# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
csv_path = "Hotness_Metrics_County_History.csv"
county_hotness_df = pd.read_csv(csv_path)
county_hotness_df.head()
# Out:
# C:\Users\tinuo\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (0,1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   month_date_yyyymm county_fips  county_name  cbsa_code  \
# 0            202108       13045  carroll, ga    12060.0
# 1            202108       22115   vernon, la    22860.0
# 2            202108       18051   gibson, in        NaN
# 3            202108       13047  catoosa, ga    16860.0
# 4            202108       13029    bryan, ga    42340.0
#
#                           cbsa_title  nielsen_hh_rank  hotness_rank  \
# 0  atlanta-sandy springs-roswell, ga            576.0         719.0
# 1                fort polk south, la            970.0        1407.0
# 2                                NaN              NaN         492.0
# 3                 chattanooga, tn-ga            806.0          73.0
# ...

# %%
county_hotness_df.set_index('month_date_yyyymm')['hotness_score'].plot();
##df_fitbit_activity.set_index('date')['steps'].plot();

# %%
#year vs median listing price
county_hotness_df.set_index('month_date_yyyymm')['median_listing_price_yy'].plot();
